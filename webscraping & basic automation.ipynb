# %%
#trivago clone for snapdeal, flipkart and amazon

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import operator
from selenium import webdriver

def snapdeal(i):
    #driver=webdriver.Chrome()
    #driver.get('https://www.snapdeal.com/search?keyword='+i+'&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&category')
    s=requests.session()
    #res=driver.execute_script('return document.documentElement.outerHTML')
    #driver.quit()
    url='https://www.snapdeal.com/search?keyword='+i+'&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&category'
    req=requests.get(url)
    soup=BeautifulSoup(req.text,'lxml')
    j=soup.findAll('p',{'product-title'})
    k=soup.findAll("span", attrs={'class':'lfloat product-price'})
    for i,m in zip(j,k):
        #print("SNAPDEAL---->"+i.text,m.text)
        name.append('SNAPDEAL  '+i.text)
        price.append(m.text)
       
    
def flipkart(i):    
    #driver=webdriver.Chrome()
    #driver.get('https://www.snapdeal.com/search?keyword='+i+'&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&category')
    s=requests.session()
    #res=driver.execute_script('return document.documentElement.outerHTML')
    #driver.quit()
    
       # b=str(s)
    url='https://www.flipkart.com/search?q='+i+'&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page='
    req=requests.get(url)
    soup=BeautifulSoup(req.text,'lxml')
    j=soup.findAll('a',{'class':'_2cLu-l'})
    k=soup.findAll('div',{'class':'_1vC4OE'})
    for i,m in zip(j,k):
            #print('FLIPKART---->'+i.text,m.text) 
        name.append(('FLIPKART  '+i.text))
        price.append((m.text))
        

        
def amazon(i):
    
    url='https://www.amazon.in/s/ref=nb_sb_noss?url=search-alias%3Daps&field-keywords='+i
    driver=webdriver.Chrome('C:/Users/Medhansh/Downloads/chromedriver_win32/chromedriver.exe')
    driver.get(url)
    #em=driver.find_element_by_tag_name('html')
    #em.send_keys(Keys.END)
    s=driver.page_source
    #time.sleep(6)
    driver.close()
    soup=BeautifulSoup(s,'lxml')
    #name=soup.findAll('h1',class_="a-size-base s-inline  s-access-title  a-text-normal")
    price=soup.findAll('span',class_="a-size-base a-color-price s-price a-text-bold")
    #print(len(s))
    # for i in name:
    #     print(i.text)
    # soup.prin
    #name
    name = soup.findAll("h2", class_="a-size-base s-inline s-access-title a-text-normal")
    for i,j in zip(name,price):
        name.append(i.text)
        price.append(j.text)

    

j=input('What you wish today------> ')
i=j.replace(' ','_')
name=[]
price=[]
flipkart(i)
snapdeal(i)
amazon(i)
#print(name)
#print(price)
d = {'Name':name,'Price':price}
#print(d)

#self.driver = webdriver.Chrome(executable_path='D:\Selenium_RiponAlWasim\Drivers\chromedriver_win32\chromedriver.exe')
#df=pd.DataFrame(d{})
#df=pd.DataFrame(d,index=)


df = pd.DataFrame(d)
#dd=df.sorted(['a', 'b'], ascending=[False,True])
#df.to_csv(" A",index=True)
#dd = df.sort_values('1')

#dd=df.sort_values('1', axis = 1, ascending = True, inplace = True, na_position ='last')
df['Price']=df['Price'].apply(lambda x: x.replace('₹','') if '₹' in str(x) else x)
df['Price']=df['Price'].apply(lambda x: x.replace(',','') if ',' in str(x) else x)

df['Price']=df['Price'].apply(lambda x: x.replace('Rs. ','') if 'Rs. ' in str(x) else x)
df['Price']=df['Price'].apply(lambda x: float(x))

df_new=df.sort_values(by='Price')
  

df_new

# %%
df['Price']=df['Price'].apply(lambda x: x.replace('₹','') if '₹' in str(x) else x)
df['Price']=df['Price'].apply(lambda x: x.replace(',','') if ',' in str(x) else x)

# %%
df['Price']=df['Price'].apply(lambda x: x.replace('Rs. ','') if 'Rs. ' in str(x) else x)
df['Price']=df['Price'].apply(lambda x: float(x))

# %%
df_price=df.sort_values(by='Price',ascending=False)

# %%
df_price
# Out:
#                                                  Name    Price
# 23  FLIPKART  Grail SD310E Spruce Semi-acoustic Gu...  18399.0
# 13       FLIPKART  Grail SD210 Spruce Acoustic Guitar  14250.0
# 43  SNAPDEAL  Kadence KAD-AM-EGBLK-C Black Electri...  12000.0
# 51  SNAPDEAL  Yamaha F310 NAT Acoustic Guitar Natu...  11214.0
# 32  FLIPKART  Kadence KAD-SH-02 Cedar Acoustic Guitar  10610.0
# 58  SNAPDEAL  Kadence Kad-Sh39-Mah Brown Acoustic ...   9792.0
# 33       FLIPKART  Grail D210C Spruce Acoustic Guitar   8750.0
# 20  FLIPKART  Kadence KAD-A-05-EQ Tonewood Acousti...   7699.0
# 25  FLIPKART  Hertz HZA-4000 EQ (SB) Linden Wood S...   7500.0
# 22   FLIPKART  Kadence AVI03 Mahogany Acoustic Guitar   6899.0
# 3        FLIPKART  Grail N120 Spruce Classical Guitar   6650.0
# 39  FLIPKART  Grail A190CE BK Basswood Semi-acoust...   6450.0
# 26  FLIPKART  Hertz HZA-4010-NA Rosewood Acoustic ...   6200.0
# 27  FLIPKART  hertz HZA-4010-BK Rosewood Acoustic ...   6200.0
# 11  FLIPKART  Kadence KAD-FNTR-BLK-SC Linden Wood ...   5750.0
# 34  FLIPKART  Kadence KAD-FNTR-SUN-C Linden Wood A...   5499.0
# 17  FLIPKART  Kadence KAD-BLK-EQ-C Spruce Acoustic...   5499.0
# 29  FLIPKART  Grail A190C SB Basswood Acoustic Guitar   5299.0
# 19     FLIPKART  Grail A190C Basswood Acoustic Guitar   5299.0
# 37  FLIPKART  Kadence KAD-FNTR-BRN-C Linden Wood A...   5150.0
# 31  FLIPKART  Signature Musicals PBVC234 Rosewood ...   4999.0
# 18  FLIPKART  Kadence KAD-BLK-C Spruce Acoustic Gu...   4999.0
# 21  FLIPKART  Signature Beatles Rosewood Acoustic ...   4999.0
# 38  FLIPKART  Signature FBK-M Tonewood Acoustic Gu...   4999.0
# 36  FLIPKART  Xtag X39C SunBurst Linden Wood Acous...   4499.0
# 49   SNAPDEAL  Zabel ZBL-ETR-BLU Blue Acoustic Guitar   4001.0
# 42  SNAPDEAL  Kadence Pro Acoustic Guitar Natural ...   3908.0
# 57  SNAPDEAL  Jixing Combo Of Red Sunburst Acousti...   3790.0
# 56  SNAPDEAL  Zabel 38 inch Acoustic Guitar with T...   3778.0
# 6   FLIPKART  Jixing JXNG-NAT-SC Linden Wood Acous...   3365.0
# 52  SNAPDEAL  KADENCE 39inch Pro Natural Spruce Wo...   3299.0
# 50  SNAPDEAL  Jixing Combo of Blue Acoustic Guitar...   3299.0
# 28  FLIPKART  Zabel ZBL-BLU-C Linden Wood Acoustic...   2999.0
# 24  FLIPKART  Zabel ZBL-RED-C Linden Wood Acoustic...   2969.0
# 35  FLIPKART  Zabel ZBL-ETR-RED-C Linden Wood Acou...   2870.0
# 15  FLIPKART  Medellin MED-BLK-C Linden Wood Acous...   2799.0
# 53      SNAPDEAL  Sonido SBC902 Brown Acoustic Guitar   2777.0
# 30  FLIPKART  Zabel ZBL-ETR-BLU-C Linden Wood Acou...   2749.0
# 14  FLIPKART  Medellin MED-BLU-C Linden Wood Acous...   2699.0
# 9   FLIPKART  Jixing DD-380C-BLU Linden Wood Acous...   2639.0
# 12  FLIPKART  Jixing JXNG-PUR-SC Linden Wood Acous...   2600.0
# 2   FLIPKART  Jixing JXNG-RED-SC Linden Wood Acous...   2600.0
# 8   FLIPKART  Jixing JXNG-BLU-SC Linden Wood Acous...   2580.0
# 48  SNAPDEAL  Zixing Acoustic Guitar Combo, Black ...   2477.0
# 41  SNAPDEAL  Zixing Acoustic Guitar Combo, Black ...   2449.0
# 45    SNAPDEAL  Jixing ZXNG-BLU-C Blue Guitar Strings   2449.0
# 46  SNAPDEAL  Sonido Acoustic Guitar SBBJ01 Natura...   2403.0
# 5   FLIPKART  Medellin MED-SUN-C Linden Wood Acous...   2390.0
# 0   FLIPKART  Juarez 38C/BLUE Linden Wood Acoustic...   2199.0
# 1   FLIPKART  Juarez JRZ38C/RED Linden Wood Acoust...   2199.0
# 10  FLIPKART  Medellin MED-NAT-C Linden Wood Acous...   2199.0
# 7   FLIPKART  Jixing DD-380C-BLK Linden Wood Acous...   2199.0
# 40    SNAPDEAL  Jixing JXNG-BLK Black Acoustic Guitar   2149.0
# 44  SNAPDEAL  Zabel ZBL-ZBTR-07 Brown Acoustic Guitar   2111.0
# 4   FLIPKART  Juarez JRZ38 /NAT Acoustic 38" Linde...   2099.0
# 16  FLIPKART  Jixing JXNG-NAT-C Linden Wood Acoust...   2050.0
# 47  SNAPDEAL  Kadence Combo of Guitar Strings, Cap...    348.0
# 54  SNAPDEAL  Kadence KAD-STR-1PACK Acoustic Guita...    300.0
# 55  SNAPDEAL  SG Musical 3pc Steel Finger Guitar P...    199.0
# 59  SNAPDEAL  Kadence KAD-10PKS-Mixed Light Teardr...    177.0

# %%
#flipkart scrapping

import requests
from bs4 import BeautifulSoup
#from selenium import webdriver

i=input('What you wish today------> ')

#driver=webdriver.Chrome()
#driver.get('https://www.snapdeal.com/search?keyword='+i+'&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&category')
s=requests.session()
#res=driver.execute_script('return document.documentElement.outerHTML')
#driver.quit()
url='https://www.flipkart.com/search?q='+i+'&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
req=requests.get(url)
soup=BeautifulSoup(req.text,'lxml')
j=soup.findAll('a',{'class':'_2cLu-l'})
for i in j:
    print(i.text)

# %%
import requests
from bs4 import BeautifulSoup
#from selenium import webdriver

i=input('What you wish today------> ')

#driver=webdriver.Chrome()
#driver.get('https://www.snapdeal.com/search?keyword='+i+'&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&category')
s=requests.session()
#res=driver.execute_script('return document.documentElement.outerHTML')
#driver.quit()

url='https://www.amazon.in/s/ref=nb_sb_noss_2?url=search-alias%3Daps&field-keywords='+i
req=requests.get(url)
s.cookies.clear()
soup=BeautifulSoup(req.text,'lxml')
j=soup.findAll('a',{'class':'a-link-normal s-access-detail-page  s-color-twister-title-link a-text-normal'})
for i in j:
    print(i.text)

# %%
#amazon scrappping
from firebase import firebase

fb=firebase.FirebaseApplication('https://grabber-55900.firebaseio.com/')
for i in range(10):
    fb.post('test',i)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-b97faac99acd> in <module>()
#       4 fb=firebase.FirebaseApplication('https://grabber-55900.firebaseio.com/')
#       5 for i in range(10):
# ----> 6     fb.post('test',i)
#
# ~\Anaconda3\lib\site-packages\firebase\decorators.py in wrapped(*args, **kwargs)
#      17             connection.timeout = timeout
#      18             connection.headers.update({'Content-type': 'application/json'})
# ---> 19             return f(*args, **kwargs)
#      20         return wraps(f)(wrapped)
#      21     return wrapper
#
# ~\Anaconda3\lib\site-packages\firebase\firebase.py in post(self, url, data, connection, params, headers)
#     327         data = json.dumps(data, cls=JSONEncoder)
#     328         return make_post_request(endpoint, data, params, headers,
# --> 329                                  connection=connection)
#     330
#     331     def post_async(self, url, data, callback=None, params=None, headers=None):
#
# ~\Anaconda3\lib\site-packages\firebase\decorators.py in wrapped(*args, **kwargs)
#      17             connection.timeout = timeout
#      18             connection.headers.update({'Content-type': 'application/json'})
# ---> 19             return f(*args, **kwargs)
#      20         return wraps(f)(wrapped)
#      21     return wrapper
#
# ~\Anaconda3\lib\site-packages\firebase\firebase.py in make_post_request(url, data, params, headers, connection)
#      99         return response.json() if response.content else None
#     100     else:
# --> 101         response.raise_for_status()
#     102
#     103
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     933
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#     937     def close(self):
#
# HTTPError: 401 Client Error: Unauthorized for url: https://grabber-55900.firebaseio.com/test/.json

# %%
import pandas as pd
x={'a':['1']}
b=pd.DataFrame(x)
b
# Out:
#    a
# 0  1

# %%
# Recursive Python program to find key  
# closest to k in given Binary Search Tree.  
  
# Utility that allocates a new node with the  
# given key and NULL left and right pointers.  
class newnode:  
  
    # Constructor to create a new node  
    def __init__(self, data):  
        self.key = data  
        self.left = None
        self.right = None
  
# Function to find node with minimum  
# absolute difference with given K  
# min_diff --> minimum difference till now  
# min_diff_key --> node having minimum absolute  
#                  difference with K  
def maxDiffUtil(ptr, k, min_diff, min_diff_key): 
    if ptr == None:  
        return
          
    # If k itself is present  
    if ptr.key == k: 
        min_diff_key[0] = k  
        return
  
    # update min_diff and min_diff_key by   
    # checking current node value  
    if min_diff > abs(ptr.key - k): 
        min_diff = abs(ptr.key - k)  
        min_diff_key[0] = ptr.key 
  
    # if k is less than ptr->key then move  
    # in left subtree else in right subtree  
    if k < ptr.key: 
        maxDiffUtil(ptr.left, k, min_diff,  
                                 min_diff_key) 
    else: 
        maxDiffUtil(ptr.right, k, min_diff,  
                                  min_diff_key) 
  
# Wrapper over maxDiffUtil()  
def maxDiff(root, k): 
      
    # Initialize minimum difference  
    min_diff, min_diff_key = 999999999999, [-1] 
  
    # Find value of min_diff_key (Closest  
    # key in tree with k)  
    maxDiffUtil(root, k, min_diff, min_diff_key) 
  
    return min_diff_key[0] 
  
# Driver Code 
if __name__ == '__main__': 
    root = newnode(10) 
    root.left = newnode(int(input()))  
    root.right = newnode(int(input())) 
    root.left.left = newnode(int(input()))  
    root.left.right = newnode(int(input())) 
    root.left.right.left = newnode(int(input()))  
    root.left.right.right = newnode(int(input()))  
    root.right.right = newnode(int(input())) 
    root.right.right.left = newnode(int(input()))  
    k = int(input('Enter the nearest number:'))
    print(maxDiff(root, k))
# Out:
# 4
# 17
# 3
# 6
# 5
# 7
# 22
# 20
# Enter the nearest number:18
# 17
